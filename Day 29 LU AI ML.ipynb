# %%
import numpy as np

# Considering sample data as follows
# X = (hours studying, hours sleeping), y = score on test
xAll = np.array(([2, 9], [1, 5], [3, 6], [5, 10]), dtype=float)  # input data
y = np.array(([92], [86], [89]), dtype=float)  # output

# scale units
xAll = xAll / np.amax(xAll, axis=0)  # scaling input data
y = y / 100  # scaling output data (max test score is 100)

# split data
X = np.split(xAll, [3])[0]  # training data
xPredicted = np.split(xAll, [3])[1]  # testing data

y = np.array(([92], [86], [89]), dtype=float)
y = y / 100  # max test score is 100


class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3

        #weights
        self.W1 = np.random.randn(
            self.inputSize,
            self.hiddenSize)  # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(
            self.hiddenSize,
            self.outputSize)  # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        #forward propagation through our network
        self.z = np.dot(
            X,
            self.W1)  # dot product of X (input) and first set of 3x2 weights
        self.z2 = self.sigmoid(self.z)  # activation function
        self.z3 = np.dot(
            self.z2, self.W2
        )  # dot product of hidden layer (z2) and second set of 3x1 weights
        o = self.sigmoid(self.z3)  # final activation function
        return o

    def sigmoid(self, s):
        # activation function
        return 1 / (1 + np.exp(-s))

    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)

    def backward(self, X, y, o):
        # backward propagate through the network
        self.o_error = y - o  # error in output
        self.o_delta = self.o_error * self.sigmoidPrime(
            o)  # applying derivative of sigmoid to error

        self.z2_error = self.o_delta.dot(
            self.W2.T
        )  # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error * self.sigmoidPrime(
            self.z2)  # applying derivative of sigmoid to z2 error

        self.W1 += X.T.dot(
            self.z2_delta)  # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(
            self.o_delta)  # adjusting second set (hidden --> output) weights

    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")

    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))


NN = Neural_Network()
for i in range(1000):  # trains the NN 1,000 times
    print("# " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" +
          str(np.mean(np.square(y - NN.forward(X)))))  # mean sum squared loss
    print("\n")
    NN.train(X, y)

NN.saveWeights()
NN.predict()
# Out:
# # 0
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.34976977]
#  [0.38447777]
#  [0.33647979]]
# Loss:
# 0.2858895107002089
#
#
# # 1
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.46484291]
#  [0.48669165]
#  [0.44788075]]
# Loss:
# 0.1806655082208092
#
#
# # 2
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.56703242]
#  [0.57556588]
#  [0.54801424]]
# Loss:
# 0.10748104644354532
#
#
# # 3
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.6419525 ]
#  [0.64062566]
#  [0.62227617]]
# Loss:
# 0.06570385411823611
#
#
# # 4
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.693628  ]
#  [0.68586481]
#  [0.67398391]]
# Loss:
# 0.04274343175039804
#
#
# # 5
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.7298752 ]
#  [0.71794531]
#  [0.71052611]]
# Loss:
# 0.02951261800188935
#
#
# # 6
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.75628691]
#  [0.74157834]
#  [0.73731297]]
# Loss:
# 0.021379664620681357
#
#
# # 7
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.77627008]
#  [0.75964123]
#  [0.75767992]]
# Loss:
# 0.01607959248975073
#
#
# # 8
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79188359]
#  [0.77388381]
#  [0.77365904]]
# Loss:
# 0.012455010564518629
#
#
# # 9
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80441078]
#  [0.78540475]
#  [0.78652476]]
# Loss:
# 0.009877480834540259
#
#
# # 10
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81468299]
#  [0.79492107]
#  [0.79710675]]
# Loss:
# 0.007985365337643597
#
#
# # 11
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82325907]
#  [0.80291825]
#  [0.80596509]]
# Loss:
# 0.006559666994639418
#
#
# # 12
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83052743]
#  [0.809736  ]
#  [0.81349044]]
# Loss:
# 0.005461840991533277
#
#
# # 13
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.836766  ]
#  [0.81561901]
#  [0.81996325]]
# Loss:
# 0.004600906174182366
#
#
# # 14
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84217877]
#  [0.82074795]
#  [0.82558992]]
# Loss:
# 0.003915175037385087
#
#
# # 15
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84691884]
#  [0.8252592 ]
#  [0.83052579]]
# Loss:
# 0.0033616533552276117
#
#
# # 16
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85110336]
#  [0.82925769]
#  [0.83488998]]
# Loss:
# 0.0029096501579123483
#
#
# # 17
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85482354]
#  [0.8328255 ]
#  [0.83877542]]
# Loss:
# 0.002536794115354303
#
#
# # 18
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85815143]
#  [0.83602783]
#  [0.84225572]]
# Loss:
# 0.00222647538746131
#
#
# # 19
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8611448 ]
#  [0.83891716]
#  [0.84538995]]
# Loss:
# 0.001966159141161348
#
#
# # 20
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86385046]
#  [0.8415362 ]
#  [0.84822609]]
# Loss:
# 0.0017462474076001995
#
#
# # 21
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86630679]
#  [0.84392015]
#  [0.85080354]]
# Loss:
# 0.0015592947439014256
#
#
# # 22
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86854558]
#  [0.84609822]
#  [0.85315498]]
# Loss:
# 0.001399457442929356
#
#
# # 23
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87059337]
#  [0.84809494]
#  [0.85530772]]
# Loss:
# 0.001262100114078982
#
#
# # 24
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8724725 ]
#  [0.849931  ]
#  [0.85728482]]
# Loss:
# 0.0011435103012300209
#
#
# # 25
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87420196]
#  [0.85162406]
#  [0.85910585]]
# Loss:
# 0.0010406885391258975
#
#
# # 26
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87579793]
#  [0.85318923]
#  [0.86078756]]
# Loss:
# 0.0009511919086794482
#
#
# # 27
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87727436]
#  [0.85463953]
#  [0.86234437]]
# Loss:
# 0.0008730160753226252
#
#
# # 28
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87864329]
#  [0.85598629]
#  [0.86378876]]
# Loss:
# 0.000804505373294101
#
#
# # 29
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8799152 ]
#  [0.85723935]
#  [0.86513158]]
# Loss:
# 0.0007442835773766861
#
#
# # 30
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88109922]
#  [0.85840735]
#  [0.86638235]]
# Loss:
# 0.0006912001054424454
#
#
# # 31
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88220341]
#  [0.85949791]
#  [0.8675494 ]]
# Loss:
# 0.0006442878505968089
#
#
# # 32
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88323485]
#  [0.86051773]
#  [0.86864011]]
# Loss:
# 0.000602729862864392
#
#
# # 33
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88419979]
#  [0.86147279]
#  [0.86966101]]
# Loss:
# 0.0005658328256257245
#
#
# # 34
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88510384]
#  [0.8623684 ]
#  [0.8706179 ]]
# Loss:
# 0.0005330057930390784
#
#
# # 35
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88595194]
#  [0.86320932]
#  [0.87151598]]
# Loss:
# 0.0005037430329932339
#
#
# # 36
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88674856]
#  [0.8639998 ]
#  [0.87235988]]
# Loss:
# 0.00047761009758286334
#
#
# # 37
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8874977 ]
#  [0.86474369]
#  [0.87315378]]
# Loss:
# 0.00045423244848816625
#
#
# # 38
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88820294]
#  [0.86544443]
#  [0.87390145]]
# Loss:
# 0.0004332861180337025
#
#
# # 39
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88886754]
#  [0.86610517]
#  [0.87460628]]
# Loss:
# 0.0004144900022175133
#
#
# # 40
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88949444]
#  [0.86672874]
#  [0.87527135]]
# Loss:
# 0.00039759946967732335
#
#
# # 41
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89008631]
#  [0.86731774]
#  [0.87589946]]
# Loss:
# 0.0003824010376006085
#
#
# # 42
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89064559]
#  [0.86787451]
#  [0.87649317]]
# Loss:
# 0.00036870791720663537
#
#
# # 43
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89117449]
#  [0.8684012 ]
#  [0.87705478]]
# Loss:
# 0.00035635627144256363
#
#
# # 44
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89167504]
#  [0.8688998 ]
#  [0.87758644]]
# Loss:
# 0.0003452020587483528
#
#
# # 45
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89214909]
#  [0.8693721 ]
#  [0.8780901 ]]
# Loss:
# 0.00033511836123870423
#
#
# # 46
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89259836]
#  [0.86981978]
#  [0.87856753]]
# Loss:
# 0.00032599311498079264
#
#
# # 47
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8930244 ]
#  [0.87024435]
#  [0.8790204 ]]
# Loss:
# 0.0003177271753856902
#
#
# # 48
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89342866]
#  [0.87064725]
#  [0.87945022]]
# Loss:
# 0.0003102326629661693
#
#
# # 49
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89381247]
#  [0.87102976]
#  [0.87985838]]
# Loss:
# 0.0003034315445207402
#
#
# # 50
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89417707]
#  [0.87139309]
#  [0.8802462 ]]
# Loss:
# 0.0002972544127023558
#
#
# # 51
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89452358]
#  [0.87173838]
#  [0.88061486]]
# Loss:
# 0.0002916394333199829
#
#
# # 52
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89485308]
#  [0.87206665]
#  [0.88096548]]
# Loss:
# 0.00028653143491340284
#
#
# # 53
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89516653]
#  [0.87237888]
#  [0.8812991 ]]
# Loss:
# 0.0002818811193776403
#
#
# # 54
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89546486]
#  [0.87267596]
#  [0.88161668]]
# Loss:
# 0.00027764437588345865
#
#
# # 55
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89574891]
#  [0.87295873]
#  [0.88191911]]
# Loss:
# 0.00027378168319349864
#
#
# # 56
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89601947]
#  [0.87322798]
#  [0.88220722]]
# Loss:
# 0.0002702575878286196
#
#
# # 57
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89627728]
#  [0.87348443]
#  [0.88248181]]
# Loss:
# 0.00026704024748898234
#
#
# # 58
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89652302]
#  [0.87372877]
#  [0.88274359]]
# Loss:
# 0.00026410103075517324
#
#
# # 59
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89675735]
#  [0.87396163]
#  [0.88299324]]
# Loss:
# 0.0002614141654458648
#
#
# # 60
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89698087]
#  [0.87418362]
#  [0.88323142]]
# Loss:
# 0.0002589564291383914
#
#
# # 61
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89719414]
#  [0.8743953 ]
#  [0.88345871]]
# Loss:
# 0.0002567068763067396
#
#
# # 62
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89739769]
#  [0.8745972 ]
#  [0.88367567]]
# Loss:
# 0.00025464659732884494
#
#
# # 63
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89759202]
#  [0.87478981]
#  [0.88388284]]
# Loss:
# 0.0002527585052881167
#
#
# # 64
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89777761]
#  [0.8749736 ]
#  [0.88408071]]
# Loss:
# 0.00025102714706321287
#
#
# # 65
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89795488]
#  [0.87514901]
#  [0.88426974]]
# Loss:
# 0.00024943853568309987
#
#
# # 66
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89812426]
#  [0.87531645]
#  [0.88445038]]
# Loss:
# 0.0002479800013349304
#
#
# # 67
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89828613]
#  [0.87547632]
#  [0.88462303]]
# Loss:
# 0.0002466400587623829
#
#
# # 68
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89844087]
#  [0.87562898]
#  [0.8847881 ]]
# Loss:
# 0.00024540828909116037
#
#
# # 69
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89858882]
#  [0.87577477]
#  [0.88494594]]
# Loss:
# 0.0002442752343745447
#
#
# # 70
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8987303 ]
#  [0.87591404]
#  [0.88509691]]
# Loss:
# 0.0002432323033717903
#
#
# # 71
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89886564]
#  [0.87604708]
#  [0.88524133]]
# Loss:
# 0.0002422716872613077
#
#
# # 72
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89899511]
#  [0.8761742 ]
#  [0.88537951]]
# Loss:
# 0.00024138628415361764
#
#
# # 73
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89911901]
#  [0.87629567]
#  [0.88551176]]
# Loss:
# 0.00024056963140994616
#
#
# # 74
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89923758]
#  [0.87641175]
#  [0.88563833]]
# Loss:
# 0.00023981584489415786
#
#
# # 75
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89935108]
#  [0.87652269]
#  [0.88575951]]
# Loss:
# 0.0002391195643915364
#
#
# # 76
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89945975]
#  [0.87662873]
#  [0.88587554]]
# Loss:
# 0.00023847590451964778
#
#
# # 77
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8995638 ]
#  [0.8767301 ]
#  [0.88598666]]
# Loss:
# 0.00023788041053646102
#
#
# # 78
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966345]
#  [0.876827  ]
#  [0.88609309]]
# Loss:
# 0.0002373290185206391
#
#
# # 79
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8997589 ]
#  [0.87691964]
#  [0.88619504]]
# Loss:
# 0.0002368180194596644
#
#
# # 80
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89985034]
#  [0.87700821]
#  [0.88629272]]
# Loss:
# 0.00023634402683473573
#
#
# # 81
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89993795]
#  [0.8770929 ]
#  [0.88638632]]
# Loss:
# 0.0002359039473380164
#
#
# # 82
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9000219 ]
#  [0.87717387]
#  [0.88647602]]
# Loss:
# 0.00023549495439868
#
#
# # 83
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90010235]
#  [0.8772513 ]
#  [0.886562  ]]
# Loss:
# 0.00023511446423021907
#
#
# # 84
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90017947]
#  [0.87732533]
#  [0.88664442]]
# Loss:
# 0.00023476011414307627
#
#
# # 85
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9002534 ]
#  [0.87739613]
#  [0.88672344]]
# Loss:
# 0.0002344297428945767
#
#
# # 86
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90032428]
#  [0.87746382]
#  [0.88679921]]
# Loss:
# 0.000234121372872782
#
#
# # 87
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90039224]
#  [0.87752855]
#  [0.88687187]]
# Loss:
# 0.0002338331939325846
#
#
# # 88
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90045741]
#  [0.87759045]
#  [0.88694156]]
# Loss:
# 0.00023356354872165795
#
#
# # 89
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90051992]
#  [0.87764963]
#  [0.8870084 ]]
# Loss:
# 0.00023331091935094075
#
#
# # 90
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90057987]
#  [0.87770622]
#  [0.88707253]]
# Loss:
# 0.00023307391527946237
#
#
# # 91
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90063739]
#  [0.87776033]
#  [0.88713405]]
# Loss:
# 0.000232851262296711
#
#
# # 92
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90069257]
#  [0.87781206]
#  [0.88719308]]
# Loss:
# 0.0002326417924977946
#
#
# # 93
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90074551]
#  [0.87786152]
#  [0.88724973]]
# Loss:
# 0.00023244443515723398
#
#
# # 94
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90079632]
#  [0.87790881]
#  [0.8873041 ]]
# Loss:
# 0.00023225820841667207
#
#
# # 95
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90084508]
#  [0.87795401]
#  [0.88735629]]
# Loss:
# 0.00023208221171038795
#
#
# # 96
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90089188]
#  [0.87799721]
#  [0.88740638]]
# Loss:
# 0.00023191561885985994
#
#
# # 97
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9009368 ]
#  [0.8780385 ]
#  [0.88745447]]
# Loss:
# 0.0002317576717755849
#
#
# # 98
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90097992]
#  [0.87807797]
#  [0.88750065]]
# Loss:
# 0.00023160767471030766
#
#
# # 99
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90102133]
#  [0.87811568]
#  [0.88754499]]
# Loss:
# 0.00023146498901319268
#
#
# # 100
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90106108]
#  [0.87815171]
#  [0.88758757]]
# Loss:
# 0.00023132902833946238
#
#
# # 101
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90109926]
#  [0.87818614]
#  [0.88762847]]
# Loss:
# 0.0002311992542742612
#
#
# # 102
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90113592]
#  [0.87821902]
#  [0.88766775]]
# Loss:
# 0.00023107517233349225
#
#
# # 103
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90117113]
#  [0.87825043]
#  [0.88770549]]
# Loss:
# 0.00023095632830788903
#
#
# # 104
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90120496]
#  [0.87828042]
#  [0.88774174]]
# Loss:
# 0.00023084230491973368
#
#
# # 105
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90123745]
#  [0.87830905]
#  [0.88777657]]
# Loss:
# 0.00023073271876447948
#
#
# # 106
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90126867]
#  [0.87833639]
#  [0.88781005]]
# Loss:
# 0.0002306272175121748
#
#
# # 107
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90129867]
#  [0.87836248]
#  [0.88784222]]
# Loss:
# 0.00023052547734583767
#
#
# # 108
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9013275 ]
#  [0.87838738]
#  [0.88787314]]
# Loss:
# 0.00023042720061601982
#
#
# # 109
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9013552 ]
#  [0.87841113]
#  [0.88790286]]
# Loss:
# 0.00023033211369278888
#
#
# # 110
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90138182]
#  [0.87843379]
#  [0.88793143]]
# Loss:
# 0.0002302399649978979
#
#
# # 111
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90140742]
#  [0.87845539]
#  [0.8879589 ]]
# Loss:
# 0.0002301505232016845
#
#
# # 112
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90143202]
#  [0.87847598]
#  [0.88798532]]
# Loss:
# 0.0002300635755703936
#
#
# # 113
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90145568]
#  [0.87849561]
#  [0.88801072]]
# Loss:
# 0.00022997892645110665
#
#
# # 114
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90147842]
#  [0.87851431]
#  [0.88803515]]
# Loss:
# 0.00022989639588244612
#
#
# # 115
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9015003 ]
#  [0.87853212]
#  [0.88805865]]
# Loss:
# 0.000229815818320373
#
#
# # 116
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90152133]
#  [0.87854908]
#  [0.88808126]]
# Loss:
# 0.00022973704146929828
#
#
# # 117
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90154157]
#  [0.87856522]
#  [0.88810301]]
# Loss:
# 0.0002296599252095685
#
#
# # 118
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90156104]
#  [0.87858058]
#  [0.88812394]]
# Loss:
# 0.00022958434061319942
#
#
# # 119
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90157976]
#  [0.87859519]
#  [0.88814408]]
# Loss:
# 0.00022951016904044187
#
#
# # 120
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90159778]
#  [0.87860907]
#  [0.88816347]]
# Loss:
# 0.00022943730131038333
#
#
# # 121
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90161512]
#  [0.87862226]
#  [0.88818213]]
# Loss:
# 0.00022936563693939124
#
#
# # 122
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90163181]
#  [0.87863479]
#  [0.88820009]]
# Loss:
# 0.0002292950834417289
#
#
# # 123
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90164788]
#  [0.87864668]
#  [0.88821739]]
# Loss:
# 0.00022922555568718559
#
#
# # 124
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90166334]
#  [0.87865796]
#  [0.88823405]]
# Loss:
# 0.00022915697531094195
#
#
# # 125
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90167823]
#  [0.87866865]
#  [0.8882501 ]]
# Loss:
# 0.00022908927017141316
#
#
# # 126
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90169257]
#  [0.87867878]
#  [0.88826555]]
# Loss:
# 0.0002290223738520235
#
#
# # 127
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90170638]
#  [0.87868837]
#  [0.88828044]]
# Loss:
# 0.00022895622520337165
#
#
# # 128
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90171968]
#  [0.87869745]
#  [0.88829479]]
# Loss:
# 0.00022889076792234855
#
#
# # 129
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90173249]
#  [0.87870602]
#  [0.88830862]]
# Loss:
# 0.00022882595016531914
#
#
# # 130
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90174484]
#  [0.87871413]
#  [0.88832195]]
# Loss:
# 0.00022876172419244423
#
#
# # 131
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90175674]
#  [0.87872177]
#  [0.8883348 ]]
# Loss:
# 0.0002286980460406597
#
#
# # 132
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90176821]
#  [0.87872898]
#  [0.88834719]]
# Loss:
# 0.0002286348752229844
#
#
# # 133
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90177926]
#  [0.87873576]
#  [0.88835914]]
# Loss:
# 0.0002285721744519345
#
#
# # 134
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90178992]
#  [0.87874214]
#  [0.88837067]]
# Loss:
# 0.0002285099093851903
#
#
# # 135
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90180019]
#  [0.87874814]
#  [0.88838179]]
# Loss:
# 0.00022844804839161138
#
#
# # 136
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90181011]
#  [0.87875376]
#  [0.88839252]]
# Loss:
# 0.0002283865623359969
#
#
# # 137
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90181967]
#  [0.87875902]
#  [0.88840287]]
# Loss:
# 0.0002283254243810822
#
#
# # 138
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90182889]
#  [0.87876395]
#  [0.88841287]]
# Loss:
# 0.0002282646098053302
#
#
# # 139
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90183779]
#  [0.87876854]
#  [0.88842252]]
# Loss:
# 0.00022820409583528724
#
#
# # 140
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90184639]
#  [0.87877282]
#  [0.88843184]]
# Loss:
# 0.00022814386149131325
#
#
# # 141
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90185468]
#  [0.8787768 ]
#  [0.88844084]]
# Loss:
# 0.00022808388744560126
#
#
# # 142
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90186269]
#  [0.87878048]
#  [0.88844954]]
# Loss:
# 0.00022802415589150276
#
#
# # 143
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90187043]
#  [0.87878389]
#  [0.88845795]]
# Loss:
# 0.00022796465042325138
#
#
# # 144
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9018779 ]
#  [0.87878703]
#  [0.88846607]]
# Loss:
# 0.00022790535592525979
#
#
# # 145
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90188512]
#  [0.87878992]
#  [0.88847393]]
# Loss:
# 0.00022784625847019907
#
#
# # 146
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9018921 ]
#  [0.87879255]
#  [0.88848152]]
# Loss:
# 0.0002277873452251751
#
#
# # 147
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90189884]
#  [0.87879496]
#  [0.88848887]]
# Loss:
# 0.00022772860436534774
#
#
# # 148
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90190536]
#  [0.87879713]
#  [0.88849598]]
# Loss:
# 0.00022767002499440937
#
#
# # 149
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90191167]
#  [0.87879909]
#  [0.88850286]]
# Loss:
# 0.00022761159707134542
#
#
# # 150
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90191777]
#  [0.87880084]
#  [0.88850952]]
# Loss:
# 0.0002275533113430183
#
#
# # 151
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90192368]
#  [0.87880239]
#  [0.88851597]]
# Loss:
# 0.00022749515928206763
#
#
# # 152
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90192939]
#  [0.87880374]
#  [0.88852222]]
# Loss:
# 0.00022743713302974112
#
#
# # 153
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90193493]
#  [0.87880491]
#  [0.88852827]]
# Loss:
# 0.00022737922534321758
#
#
# # 154
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90194028]
#  [0.87880591]
#  [0.88853414]]
# Loss:
# 0.0002273214295471359
#
#
# # 155
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90194547]
#  [0.87880673]
#  [0.88853983]]
# Loss:
# 0.0002272637394889109
#
#
# # 156
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019505 ]
#  [0.87880739]
#  [0.88854534]]
# Loss:
# 0.0002272061494976056
#
#
# # 157
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90195538]
#  [0.8788079 ]
#  [0.88855069]]
# Loss:
# 0.00022714865434602497
#
#
# # 158
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019601 ]
#  [0.87880825]
#  [0.88855588]]
# Loss:
# 0.00022709124921583258
#
#
# # 159
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90196469]
#  [0.87880846]
#  [0.88856092]]
# Loss:
# 0.00022703392966538823
#
#
# # 160
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90196913]
#  [0.87880854]
#  [0.88856582]]
# Loss:
# 0.00022697669160013086
#
#
# # 161
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90197345]
#  [0.87880848]
#  [0.88857057]]
# Loss:
# 0.00022691953124530492
#
#
# # 162
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90197764]
#  [0.87880829]
#  [0.88857519]]
# Loss:
# 0.0002268624451208165
# # 163
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90198171]
#  [0.87880798]
#  [0.88857967]]
# Loss:
# 0.00022680543001809127
#
#
# # 164
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90198566]
#  [0.87880755]
#  [0.88858404]]
# Loss:
# 0.00022674848297873942
#
#
# # 165
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019895 ]
#  [0.87880701]
#  [0.88858828]]
# Loss:
# 0.00022669160127489557
#
#
# # 166
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90199323]
#  [0.87880636]
#  [0.88859241]]
# Loss:
# 0.00022663478239112183
#
#
# # 167
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90199686]
#  [0.87880561]
#  [0.88859643]]
# Loss:
# 0.0002265780240077272
#
#
# # 168
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90200039]
#  [0.87880476]
#  [0.88860035]]
# Loss:
# 0.00022652132398539223
#
#
# # 169
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90200383]
#  [0.87880382]
#  [0.88860416]]
# Loss:
# 0.00022646468035100403
#
#
# # 170
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90200717]
#  [0.87880278]
#  [0.88860788]]
# Loss:
# 0.0002264080912846199
#
#
# # 171
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90201043]
#  [0.87880165]
#  [0.8886115 ]]
# Loss:
# 0.00022635155510743695
#
#
# # 172
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9020136 ]
#  [0.87880044]
#  [0.88861503]]
# Loss:
# 0.00022629507027071376
#
#
# # 173
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9020167 ]
#  [0.87879915]
#  [0.88861848]]
# Loss:
# 0.00022623863534555763
#
#
# # 174
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90201971]
#  [0.87879778]
#  [0.88862184]]
# Loss:
# 0.00022618224901353352
#
#
# # 175
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90202265]
#  [0.87879634]
#  [0.88862513]]
# Loss:
# 0.00022612591005798078
#
#
# # 176
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90202552]
#  [0.87879483]
#  [0.88862833]]
# Loss:
# 0.00022606961735603868
#
#
# # 177
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90202832]
#  [0.87879325]
#  [0.88863147]]
# Loss:
# 0.0002260133698712734
#
#
# # 178
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90203106]
#  [0.8787916 ]
#  [0.88863453]]
# Loss:
# 0.0002259571666469004
#
#
# # 179
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90203373]
#  [0.87878989]
#  [0.88863753]]
# Loss:
# 0.00022590100679954436
#
#
# # 180
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90203634]
#  [0.87878812]
#  [0.88864046]]
# Loss:
# 0.0002258448895134699
#
#
# # 181
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90203889]
#  [0.87878629]
#  [0.88864333]]
# Loss:
# 0.00022578881403526602
#
#
# # 182
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90204139]
#  [0.8787844 ]
#  [0.88864614]]
# Loss:
# 0.00022573277966898324
#
#
# # 183
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90204383]
#  [0.87878246]
#  [0.88864889]]
# Loss:
# 0.0002256767857715898
#
#
# # 184
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90204622]
#  [0.87878047]
#  [0.88865158]]
# Loss:
# 0.0002256208317488489
#
#
# # 185
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90204857]
#  [0.87877844]
#  [0.88865423]]
# Loss:
# 0.0002255649170514721
#
#
# # 186
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205086]
#  [0.87877635]
#  [0.88865682]]
# Loss:
# 0.00022550904117160016
#
#
# # 187
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205311]
#  [0.87877422]
#  [0.88865936]]
# Loss:
# 0.00022545320363953974
#
#
# # 188
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205531]
#  [0.87877205]
#  [0.88866186]]
# Loss:
# 0.00022539740402079266
#
#
# # 189
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205747]
#  [0.87876983]
#  [0.88866431]]
# Loss:
# 0.00022534164191327126
#
#
# # 190
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205959]
#  [0.87876758]
#  [0.88866672]]
# Loss:
# 0.00022528591694475435
#
#
# # 191
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90206168]
#  [0.87876528]
#  [0.88866908]]
# Loss:
# 0.00022523022877056668
#
#
# # 192
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90206372]
#  [0.87876295]
#  [0.88867141]]
# Loss:
# 0.00022517457707139
#
#
# # 193
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90206573]
#  [0.87876059]
#  [0.88867369]]
# Loss:
# 0.0002251189615512793
#
#
# # 194
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9020677 ]
#  [0.87875819]
#  [0.88867595]]
# Loss:
# 0.00022506338193584123
#
#
# # 195
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90206964]
#  [0.87875576]
#  [0.88867816]]
# Loss:
# 0.00022500783797052318
#
#
# # 196
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90207155]
#  [0.8787533 ]
#  [0.88868034]]
# Loss:
# 0.0002249523294190715
#
#
# # 197
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90207343]
#  [0.87875081]
#  [0.88868249]]
# Loss:
# 0.00022489685606207963
#
#
# # 198
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90207528]
#  [0.87874829]
#  [0.8886846 ]]
# Loss:
# 0.00022484141769567358
#
#
# # 199
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9020771 ]
#  [0.87874575]
#  [0.88868669]]
# Loss:
# 0.00022478601413029742
#
#
# # 200
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9020789 ]
#  [0.87874317]
#  [0.88868875]]
# Loss:
# 0.00022473064518957017
#
#
# # 201
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208066]
#  [0.87874058]
#  [0.88869078]]
# Loss:
# 0.00022467531070926528
#
#
# # 202
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208241]
#  [0.87873796]
#  [0.88869278]]
# Loss:
# 0.0002246200105363537
#
#
# # 203
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208412]
#  [0.87873531]
#  [0.88869476]]
# Loss:
# 0.00022456474452812883
#
#
# # 204
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208582]
#  [0.87873265]
#  [0.88869671]]
# Loss:
# 0.00022450951255136942
#
#
# # 205
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208749]
#  [0.87872996]
#  [0.88869864]]
# Loss:
# 0.0002244543144816279
#
#
# # 206
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208914]
#  [0.87872726]
#  [0.88870054]]
# Loss:
# 0.00022439915020252467
#
#
# # 207
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209078]
#  [0.87872453]
#  [0.88870242]]
# Loss:
# 0.0002243440196051067
#
#
# # 208
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209239]
#  [0.87872179]
#  [0.88870429]]
# Loss:
# 0.00022428892258727275
#
#
# # 209
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209398]
#  [0.87871903]
#  [0.88870613]]
# Loss:
# 0.00022423385905323678
#
#
# # 210
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209555]
#  [0.87871625]
#  [0.88870795]]
# Loss:
# 0.0002241788289130296
#
#
# # 211
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209711]
#  [0.87871345]
#  [0.88870975]]
# Loss:
# 0.0002241238320820219
#
#
# # 212
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90209865]
#  [0.87871064]
#  [0.88871154]]
# Loss:
# 0.00022406886848054387
#
#
# # 213
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210017]
#  [0.87870782]
#  [0.88871331]]
# Loss:
# 0.00022401393803345398
#
#
# # 214
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210168]
#  [0.87870498]
#  [0.88871506]]
# Loss:
# 0.00022395904066980566
#
#
# # 215
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210318]
#  [0.87870213]
#  [0.88871679]]
# Loss:
# 0.00022390417632251318
#
#
# # 216
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210466]
#  [0.87869926]
#  [0.88871851]]
# Loss:
# 0.00022384934492804308
#
#
# # 217
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210612]
#  [0.87869639]
#  [0.88872022]]
# Loss:
# 0.00022379454642613872
#
#
# # 218
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210757]
#  [0.8786935 ]
#  [0.88872191]]
# Loss:
# 0.00022373978075956085
#
#
# # 219
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210901]
#  [0.8786906 ]
#  [0.88872359]]
# Loss:
# 0.00022368504787384752
#
#
# # 220
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211044]
#  [0.87868769]
#  [0.88872525]]
# Loss:
# 0.00022363034771710074
#
#
# # 221
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211185]
#  [0.87868477]
#  [0.8887269 ]]
# Loss:
# 0.00022357568023978
#
#
# # 222
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211326]
#  [0.87868184]
#  [0.88872854]]
# Loss:
# 0.00022352104539451225
#
#
# # 223
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211465]
#  [0.8786789 ]
#  [0.88873017]]
# Loss:
# 0.00022346644313594294
#
#
# # 224
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211603]
#  [0.87867595]
#  [0.88873178]]
# Loss:
# 0.000223411873420533
#
#
# # 225
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211741]
#  [0.87867299]
#  [0.88873339]]
# Loss:
# 0.00022335733620647342
#
#
# # 226
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211877]
#  [0.87867002]
#  [0.88873498]]
# Loss:
# 0.00022330283145349314
#
#
# # 227
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212012]
#  [0.87866705]
#  [0.88873657]]
# Loss:
# 0.00022324835912278335
#
#
# # 228
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212147]
#  [0.87866407]
#  [0.88873814]]
# Loss:
# 0.00022319391917685258
#
#
# # 229
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9021228 ]
#  [0.87866108]
#  [0.88873971]]
# Loss:
# 0.0002231395115794329
#
#
# # 230
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212413]
#  [0.87865809]
#  [0.88874127]]
# Loss:
# 0.00022308513629538214
#
#
# # 231
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212545]
#  [0.87865509]
#  [0.88874282]]
# Loss:
# 0.00022303079329060563
#
#
# # 232
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212676]
#  [0.87865208]
#  [0.88874436]]
# Loss:
# 0.0002229764825319549
# # 233
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212807]
#  [0.87864907]
#  [0.88874589]]
# Loss:
# 0.000222922203987161
#
#
# # 234
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90212936]
#  [0.87864605]
#  [0.88874741]]
# Loss:
# 0.00022286795762478225
#
#
# # 235
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213065]
#  [0.87864303]
#  [0.88874893]]
# Loss:
# 0.00022281374341410792
#
#
# # 236
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213194]
#  [0.87864   ]
#  [0.88875044]]
# Loss:
# 0.00022275956132512264
#
#
# # 237
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213322]
#  [0.87863697]
#  [0.88875194]]
# Loss:
# 0.00022270541132845046
#
#
# # 238
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213449]
#  [0.87863393]
#  [0.88875344]]
# Loss:
# 0.00022265129339528794
#
#
# # 239
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213575]
#  [0.87863089]
#  [0.88875493]]
# Loss:
# 0.0002225972074973886
#
#
# # 240
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213701]
#  [0.87862785]
#  [0.88875642]]
# Loss:
# 0.00022254315360699546
#
#
# # 241
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213827]
#  [0.8786248 ]
#  [0.88875789]]
# Loss:
# 0.00022248913169679787
#
#
# # 242
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213952]
#  [0.87862175]
#  [0.88875937]]
# Loss:
# 0.00022243514173992396
#
#
# # 243
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214076]
#  [0.87861869]
#  [0.88876083]]
# Loss:
# 0.00022238118370987938
#
#
# # 244
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.902142  ]
#  [0.87861563]
#  [0.8887623 ]]
# Loss:
# 0.0002223272575805419
#
#
# # 245
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214324]
#  [0.87861257]
#  [0.88876375]]
# Loss:
# 0.00022227336332611032
#
#
# # 246
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214447]
#  [0.8786095 ]
#  [0.8887652 ]]
# Loss:
# 0.00022221950092108636
#
#
# # 247
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214569]
#  [0.87860644]
#  [0.88876665]]
# Loss:
# 0.00022216567034026067
#
#
# # 248
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214691]
#  [0.87860337]
#  [0.88876809]]
# Loss:
# 0.00022211187155868505
#
#
# # 249
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214813]
#  [0.8786003 ]
#  [0.88876953]]
# Loss:
# 0.0002220581045516386
#
#
# # 250
#
# ...
#  [0.89]]
# Predicted Output:
# [[0.90282312]
#  [0.87677746]
#  [0.88956138]]
# Loss:
# 0.00019224022795104917
#
#
# # 918
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282402]
#  [0.87677511]
#  [0.8895624 ]]
# Loss:
# 0.00019220339193093294
#
#
# # 919
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282491]
#  [0.87677276]
#  [0.88956343]]
# Loss:
# 0.00019216657571849275
#
#
# # 920
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282581]
#  [0.87677042]
#  [0.88956446]]
# Loss:
# 0.00019212977929986604
#
#
# # 921
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282671]
#  [0.87676807]
#  [0.88956549]]
# Loss:
# 0.00019209300266119438
#
#
# # 922
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028276 ]
#  [0.87676573]
#  [0.88956651]]
# Loss:
# 0.00019205624578863109
#
#
# # 923
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028285 ]
#  [0.87676339]
#  [0.88956754]]
# Loss:
# 0.00019201950866833337
#
#
# # 924
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028294 ]
#  [0.87676104]
#  [0.88956857]]
# Loss:
# 0.00019198279128648145
#
#
# # 925
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283029]
#  [0.8767587 ]
#  [0.88956959]]
# Loss:
# 0.00019194609362925468
#
#
# # 926
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283119]
#  [0.87675636]
#  [0.88957062]]
# Loss:
# 0.00019190941568284764
#
#
# # 927
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283208]
#  [0.87675402]
#  [0.88957164]]
# Loss:
# 0.0001918727574334642
#
#
# # 928
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283297]
#  [0.87675169]
#  [0.88957266]]
# Loss:
# 0.00019183611886731575
#
#
# # 929
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283387]
#  [0.87674935]
#  [0.88957369]]
# Loss:
# 0.00019179949997062803
#
#
# # 930
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283476]
#  [0.87674701]
#  [0.88957471]]
# Loss:
# 0.00019176290072963576
#
#
# # 931
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283566]
#  [0.87674468]
#  [0.88957573]]
# Loss:
# 0.00019172632113057775
#
#
# # 932
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283655]
#  [0.87674235]
#  [0.88957676]]
# Loss:
# 0.0001916897611597168
#
#
# # 933
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283744]
#  [0.87674001]
#  [0.88957778]]
# Loss:
# 0.00019165322080331245
#
#
# # 934
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283834]
#  [0.87673768]
#  [0.8895788 ]]
# Loss:
# 0.00019161670004763794
#
#
# # 935
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90283923]
#  [0.87673535]
#  [0.88957982]]
# Loss:
# 0.00019158019887897723
#
#
# # 936
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284012]
#  [0.87673302]
#  [0.88958084]]
# Loss:
# 0.0001915437172836293
#
#
# # 937
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284101]
#  [0.87673069]
#  [0.88958186]]
# Loss:
# 0.0001915072552478946
#
#
# # 938
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028419 ]
#  [0.87672836]
#  [0.88958288]]
# Loss:
# 0.0001914708127580928
#
#
# # 939
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284279]
#  [0.87672604]
#  [0.8895839 ]]
# Loss:
# 0.00019143438980054504
#
#
# # 940
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284369]
#  [0.87672371]
#  [0.88958492]]
# Loss:
# 0.00019139798636158632
#
#
# # 941
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284458]
#  [0.87672139]
#  [0.88958594]]
# Loss:
# 0.00019136160242756337
#
#
# # 942
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284547]
#  [0.87671906]
#  [0.88958696]]
# Loss:
# 0.00019132523798483044
#
#
# # 943
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284636]
#  [0.87671674]
#  [0.88958797]]
# Loss:
# 0.0001912888930197522
#
#
# # 944
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284725]
#  [0.87671442]
#  [0.88958899]]
# Loss:
# 0.00019125256751870853
#
#
# # 945
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284814]
#  [0.8767121 ]
#  [0.88959001]]
# Loss:
# 0.0001912162614680782
#
#
# # 946
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284903]
#  [0.87670978]
#  [0.88959102]]
# Loss:
# 0.00019117997485426023
#
#
# # 947
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284991]
#  [0.87670746]
#  [0.88959204]]
# Loss:
# 0.00019114370766365764
#
#
# # 948
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028508 ]
#  [0.87670514]
#  [0.88959305]]
# Loss:
# 0.0001911074598826874
#
#
# # 949
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285169]
#  [0.87670283]
#  [0.88959407]]
# Loss:
# 0.00019107123149777919
#
#
# # 950
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285258]
#  [0.87670051]
#  [0.88959508]]
# Loss:
# 0.00019103502249535916
#
#
# # 951
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285347]
#  [0.8766982 ]
#  [0.8895961 ]]
# Loss:
# 0.00019099883286187862
#
#
# # 952
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285435]
#  [0.87669588]
#  [0.88959711]]
# Loss:
# 0.00019096266258379393
#
#
# # 953
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285524]
#  [0.87669357]
#  [0.88959813]]
# Loss:
# 0.0001909265116475657
#
#
# # 954
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285613]
#  [0.87669126]
#  [0.88959914]]
# Loss:
# 0.0001908903800396731
#
#
# # 955
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285702]
#  [0.87668895]
#  [0.88960015]]
# Loss:
# 0.0001908542677466033
#
#
# # 956
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028579 ]
#  [0.87668664]
#  [0.88960116]]
# Loss:
# 0.00019081817475484594
#
#
# # 957
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285879]
#  [0.87668433]
#  [0.88960217]]
# Loss:
# 0.00019078210105091082
#
#
# # 958
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285967]
#  [0.87668202]
#  [0.88960319]]
# Loss:
# 0.0001907460466213079
#
#
# # 959
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286056]
#  [0.87667972]
#  [0.8896042 ]]
# Loss:
# 0.00019071001145257106
#
#
# # 960
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286144]
#  [0.87667741]
#  [0.88960521]]
# Loss:
# 0.00019067399553122802
#
#
# # 961
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286233]
#  [0.87667511]
#  [0.88960622]]
# Loss:
# 0.0001906379988438268
#
#
# # 962
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286321]
#  [0.8766728 ]
#  [0.88960723]]
# Loss:
# 0.00019060202137692153
#
#
# # 963
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028641 ]
#  [0.8766705 ]
#  [0.88960824]]
# Loss:
# 0.00019056606311707654
#
#
# # 964
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286498]
#  [0.8766682 ]
#  [0.88960924]]
# Loss:
# 0.000190530124050869
#
#
# # 965
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286587]
#  [0.8766659 ]
#  [0.88961025]]
# Loss:
# 0.00019049420416488078
#
#
# # 966
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286675]
#  [0.8766636 ]
#  [0.88961126]]
# Loss:
# 0.00019045830344570933
#
#
# # 967
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286763]
#  [0.8766613 ]
#  [0.88961227]]
# Loss:
# 0.00019042242187995536
#
#
# # 968
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90286852]
#  [0.876659  ]
#  [0.88961327]]
# Loss:
# 0.0001903865594542378
#
#
# # 969
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028694 ]
#  [0.87665671]
#  [0.88961428]]
# Loss:
# 0.00019035071615517644
#
#
# # 970
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287028]
#  [0.87665441]
#  [0.88961529]]
# Loss:
# 0.00019031489196941374
#
#
# # 971
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287116]
#  [0.87665212]
#  [0.88961629]]
# Loss:
# 0.0001902790868835837
#
#
# # 972
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287204]
#  [0.87664982]
#  [0.8896173 ]]
# Loss:
# 0.00019024330088434388
#
#
# # 973
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287293]
#  [0.87664753]
#  [0.8896183 ]]
# Loss:
# 0.00019020753395835818
#
#
# # 974
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287381]
#  [0.87664524]
#  [0.88961931]]
# Loss:
# 0.000190171786092302
#
#
# # 975
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287469]
#  [0.87664295]
#  [0.88962031]]
# Loss:
# 0.00019013605727285815
#
#
# # 976
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287557]
#  [0.87664066]
#  [0.88962132]]
# Loss:
# 0.00019010034748671552
#
#
# # 977
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287645]
#  [0.87663837]
#  [0.88962232]]
# Loss:
# 0.00019006465672058212
#
#
# # 978
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287733]
#  [0.87663608]
#  [0.88962332]]
# Loss:
# 0.00019002898496116956
#
#
# # 979
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287821]
#  [0.87663379]
#  [0.88962432]]
# Loss:
# 0.00018999333219520085
#
#
# # 980
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287909]
#  [0.87663151]
#  [0.88962533]]
# Loss:
# 0.00018995769840940633
#
#
# # 981
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287997]
#  [0.87662922]
#  [0.88962633]]
# Loss:
# 0.00018992208359053014
#
#
# # 982
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288085]
#  [0.87662694]
#  [0.88962733]]
# Loss:
# 0.0001898864877253278
#
#
# # 983
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288172]
#  [0.87662466]
#  [0.88962833]]
# Loss:
# 0.00018985091080055467
#
#
# # 984
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028826 ]
#  [0.87662238]
#  [0.88962933]]
# Loss:
# 0.00018981535280298634
#
#
# # 985
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288348]
#  [0.8766201 ]
#  [0.88963033]]
# Loss:
# 0.00018977981371940048
#
#
# # 986
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288436]
#  [0.87661782]
#  [0.88963133]]
# Loss:
# 0.00018974429353659503
#
#
# # 987
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288524]
#  [0.87661554]
#  [0.88963233]]
# Loss:
# 0.00018970879224136303
#
#
# # 988
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288611]
#  [0.87661326]
#  [0.88963333]]
# Loss:
# 0.000189673309820522
#
#
# # 989
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288699]
#  [0.87661098]
#  [0.88963432]]
# Loss:
# 0.00018963784626088872
#
#
# # 990
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288787]
#  [0.87660871]
#  [0.88963532]]
# Loss:
# 0.00018960240154929325
#
#
# # 991
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288874]
#  [0.87660643]
#  [0.88963632]]
# Loss:
# 0.00018956697567257838
#
#
# # 992
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288962]
#  [0.87660416]
#  [0.88963731]]
# Loss:
# 0.00018953156861759035
#
#
# # 993
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9028905 ]
#  [0.87660189]
#  [0.88963831]]
# Loss:
# 0.00018949618037119307
#
#
# # 994
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90289137]
#  [0.87659961]
#  [0.88963931]]
# Loss:
# 0.00018946081092025154
#
#
# # 995
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90289225]
#  [0.87659734]
#  [0.8896403 ]]
# Loss:
# 0.00018942546025164174
#
#
# # 996
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90289312]
#  [0.87659507]
#  [0.8896413 ]]
# Loss:
# 0.00018939012835225984
#
#
# # 997
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.902894  ]
#  [0.8765928 ]
#  [0.88964229]]
# Loss:
# 0.00018935481520899807
#
#
# # 998
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90289487]
#  [0.87659054]
#  [0.88964329]]
# Loss:
# 0.0001893195208087649
#
#
# # 999
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90289575]
#  [0.87658827]
#  [0.88964428]]
# Loss:
# 0.00018928424513848464
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [[1. 1.]]
# Output:
# [[0.90149888]]
